# %% [markdown]
# <a href="https://colab.research.google.com/github/SahilRazaKhan7607/Our_first_ML_model/blob/main/OurFirstML_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is our first ML model,with a very tiny data.

# %%
from sklearn.tree import DecisionTreeClassifier
feature=[
    [150,0], #apply
    [170,0], #apple
    [130,0], #orange
    [120,0], #orange
]
labels=["apple","apple","orange","orange"]
clf=DecisionTreeClassifier()
clf=clf.fit(feature,labels)
print("The fruit is ",clf.predict([[180,0]]))
# Out:
# The fruit is  ['apple']

# %% [markdown]
# logic/Blueprint

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt;
plt.figure(figsize=(11,6))
plot_tree(clf,feature_names=["weight","color"],class_names=["apple","orange"],filled=True)
# Out:
# [Text(0.5, 0.75, 'weight <= 140.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = apple'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = orange'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = apple'),
#  Text(0.625, 0.5, '  False')]
